# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.linear_model import LinearRegression
from datetime import datetime

# %%
db_path = './data/cruise_pre.db'
conn = sqlite3.connect(db_path)
cruise_pre_data = pd.read_sql_query(sql="SELECT * FROM cruise_pre", con=conn)
# cruise_pre_data.head()
cruise_pre_data = cruise_pre_data.drop(['index','Logging'], axis=1)
cruise_pre_data.shape
# Out:
# (133746, 17)

# %%
db_path = './data/cruise_post.db'
conn = sqlite3.connect(db_path)
cruise_post_data = pd.read_sql_query(sql="SELECT * FROM cruise_post", con=conn)
# cruise_post_data.head()
cruise_post_data = cruise_post_data.drop(['index'], axis=1)
cruise_post_data.shape
# Out:
# (133746, 7)

# %%
# Fill the empty field for rows with same "Ext_Intcode" using forward and backwards fill
# This is to facilitate the dropping of duplicate rows

cruise_pre_data = cruise_pre_data.set_index('Ext_Intcode').groupby("Ext_Intcode").fillna(method="ffill").reset_index()
cruise_pre_data = cruise_pre_data.set_index('Ext_Intcode').groupby("Ext_Intcode").fillna(method="bfill").reset_index()


cruise_post_data = cruise_post_data.set_index('Ext_Intcode').groupby("Ext_Intcode").fillna(method="ffill").reset_index()
cruise_post_data = cruise_post_data.set_index('Ext_Intcode').groupby("Ext_Intcode").fillna(method="bfill").reset_index()

# %%
# # Check for cruise_pre duplicate
# duplicate_pre_rows = cruise_pre_data[cruise_pre_data.duplicated()]

# # # Shows cruise_pre duplicate
# print("Duplicate Rows (excluding first occurrence):")
# print(duplicate_pre_rows)

# Remove cruise_pre duplicate rows
cruise_pre_data = cruise_pre_data.drop_duplicates()
print("Shape of cruise_pre_data after droping duplicate:")
cruise_pre_data.shape
# Out:
# Number of rows and columns for pre_cruise after droping duplicate:
# (129850, 17)

# %%
# # Check for cruise_post duplicate
# duplicate_post_rows = cruise_post_data[cruise_post_data.duplicated()]

# # # Shows cruise_post duplicate
# print("Duplicate Rows (excluding first occurrence):")
# print(duplicate_post_rows)

# Remove cruise_post duplicate rows
cruise_post_data = cruise_post_data.drop_duplicates()
print("Shape of cruise_post_data after droping duplicate:")
cruise_post_data.shape
# Out:
# Number of rows and columns for post_cruise after droping duplicate:
# (129850, 7)

# %%
# Perform the join operation on the 'Ext_Intcode' column
cruise_merge_data = pd.merge(cruise_pre_data, cruise_post_data, on='Ext_Intcode', how='inner')
cruise_merge_data.head()
print("Shape of cruise_merge_data after merging:")
cruise_merge_data.shape

# Save the resulting DataFrame to a CSV file
cruise_merge_data.to_csv('cruise_merge.csv', index=False)
# Out:
# Number of rows and columns for after merging cruise_post and cruise_pre:
# (129850, 23)

# %%
cruise_merge_data = pd.read_csv('cruise_merge.csv')

# Define a function to convert the values to integers
def convert_to_integer(value):
    if value is not np.nan and isinstance(value, str):
        parts = value.split()
        if len(parts) == 2:
            numeric_part, unit = parts
            if unit == "KM":
                return int(numeric_part)
            elif unit == "Miles":
                # Convert Miles to KM (1 Mile = 1.60934 KM)
                return int(float(numeric_part) * 1.60934)
    return np.nan

# Apply the function to the DataFrame column
cruise_merge_data['Cruise Distance'] = cruise_merge_data['Cruise Distance'].apply(convert_to_integer)

cruise_merge_data.head()
# Out:
#    Ext_Intcode  Gender Date of Birth         Source of Traffic  \
# 0  LB446RWOOZI     NaN    05/10/1973  Direct - Company Website
# 1  LB138HKBECM  Female           NaN   Indirect - Social Media
# 2  BL713UHBAAN  Female    22/07/1998  Indirect - Search Engine
# 3  LB243DMKCFL  Female    01/05/1970  Direct - Company Website
# 4  LB218CFLOBS    Male    07/01/1960  Direct - Company Website
#
#    Onboard Wifi Service  Embarkation/Disembarkation time convenient  \
# 0    A little important                                         3.0
# 1  Not at all important                                         4.0
# 2                   NaN                                         3.0
# 3        Very important                                         4.0
# 4    Somewhat important                                         4.0
#
#    Ease of Online booking  Gate location Onboard Dining Service  \
# 0                     5.0            3.0         Very important
# 1                     1.0            NaN         Very important
# 2                     0.0            5.0                    NaN
# 3                     4.0            4.0     Somewhat important
# 4                     2.0            NaN   Not at all important
#
#    Online Check-in  ...  Baggage handling Port Check-in Service  \
# 0              2.0  ...               2.0                   4.0
# 1              NaN  ...               3.0                   4.0
# 2              NaN  ...               1.0                   2.0
# 3              4.0  ...               NaN                   3.0
# 4              2.0  ...               3.0                   5.0
#
#    Onboard Service  Cleanliness  Cruise Name  Ticket Type  Cruise Distance  \
# 0              2.0          3.0    Blastoise          NaN           3567.0
# 1              4.0          4.0    Blastoise       Deluxe            672.0
# 2              3.0          NaN       IAPRAS       Deluxe           1167.0
# 3              2.0          4.0       Lapras       Deluxe            280.0
# 4              2.0          1.0       Lapras     Standard           1842.0
#
#   WiFi Dining  Entertainment
# 0  1.0      1            1.0
# 1  NaN      0            1.0
# 2  NaN      0            0.0
# 3  NaN      0            1.0
# 4  NaN      1            NaN
#
# [5 rows x 23 columns]

# %%
# Convert the "date_text" column to datetime format
cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])

# Specify date formats explicitly for parsing
date_formats = ['%Y-%m-%d', '%d/%m/%Y']

# Convert the "date_of_birth" column to datetime, handling multiple formats
cruise_merge_data['Date of Birth'] = pd.to_datetime(cruise_merge_data['Date of Birth'], format= date_formats, errors='coerce')


# Get the current date
current_date = datetime.now()

# Calculate the age and create an "age" column
cruise_merge_data['age'] = (current_date - cruise_merge_data['Date of Birth']).astype('<m8[Y]')

cruise_merge_data.head()

# Save the resulting DataFrame to a CSV file
# cruise_merge_data.to_csv('cruise_merge_age.csv', index=False)

# Drop irrelavant and dependent column
cruise_merge_data.drop(['Ext_Intcode','Date of Birth' ,'Ticket Type'],axis=1, inplace=True)
cruise_merge_data.shape
# Out:
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/07/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/12/1986' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/03/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/12/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/07/1980' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/05/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/03/1989' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/08/1989' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/07/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/06/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/10/1965' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/02/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/04/1979' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/07/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/09/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/03/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/03/1977' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/07/1994' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/03/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/07/1985' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/11/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/08/1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/02/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/11/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/04/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/05/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/05/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/06/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/06/1971' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/08/1974' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/01/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/06/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/08/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/06/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/06/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/02/1959' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/04/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/09/1986' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/01/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/07/1963' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/08/1971' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/06/1990' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/03/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/10/1974' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/03/1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/07/1965' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/11/1974' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/04/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/04/1999' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/12/1991' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/11/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/08/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/07/1990' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/04/1994' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/10/1960' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/10/1951' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/05/1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/08/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/10/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/04/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/11/1982' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/01/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/10/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/02/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/05/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/10/1956' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/08/1966' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/10/1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/04/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/12/1976' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/03/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/08/1978' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/08/1971' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/05/1973' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/08/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/04/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/02/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/11/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/03/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/06/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/08/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/04/1990' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/05/1973' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/06/1988' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/02/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/09/1965' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/06/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/04/1995' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/10/1971' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/11/1995' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/02/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/09/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/10/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/11/1988' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/12/1989' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/08/1974' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/12/1953' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/02/1986' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/01/1989' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/03/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/01/1979' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/08/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/05/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/03/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/12/1986' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/10/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/09/1999' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/06/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/06/1964' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/12/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/01/1978' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/03/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/01/1979' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/07/1955' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/02/1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/05/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/05/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/05/1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/09/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/11/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/12/1995' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/03/1964' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/03/1998' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/09/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/09/1978' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/04/1976' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/07/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/06/1974' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/03/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/12/1952' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/10/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/11/1979' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/03/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/02/1988' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/01/1978' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/07/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/03/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/05/1973' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/07/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/09/1999' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/12/1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/04/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/05/1960' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/11/1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/01/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/09/1991' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/05/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/12/1999' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/11/1958' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/09/1938' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/05/1978' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/10/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/10/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/01/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# ...
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/06/1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/06/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/01/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/06/1982' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/05/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '22/01/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/10/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/09/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/03/1972' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/03/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/12/1981' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/06/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/09/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/04/1954' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/05/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/12/1987' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/07/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/03/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/10/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/07/1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/09/1986' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '24/05/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/03/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/06/1962' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '20/11/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/01/1955' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/04/1969' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '26/09/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/10/1954' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '14/09/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/10/1963' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/05/1976' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/02/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/04/1967' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '13/01/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '16/11/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/10/1961' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '19/05/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/10/1999' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/02/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/09/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '23/08/1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '25/04/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '28/01/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '15/05/1982' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/09/1968' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '27/09/1983' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/10/1943' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '21/06/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '18/10/1956' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# C:\Users\thedi\AppData\Local\Temp/ipykernel_17828/592375043.py:2: UserWarning: Parsing '17/10/1957' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cruise_merge_data['Date of Birth']= pd.to_datetime(cruise_merge_data['Date of Birth'])
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
cruise_merge_data.dtypes
# Out:
# Gender                                         object
# Source of Traffic                              object
# Onboard Wifi Service                           object
# Embarkation/Disembarkation time convenient    float64
# Ease of Online booking                        float64
# Gate location                                 float64
# Onboard Dining Service                         object
# Online Check-in                               float64
# Cabin Comfort                                 float64
# Onboard Entertainment                          object
# Cabin service                                 float64
# Baggage handling                              float64
# Port Check-in Service                         float64
# Onboard Service                               float64
# Cleanliness                                   float64
# Cruise Name                                    object
# Cruise Distance                               float64
# WiFi                                          float64
# Dining                                          int64
# Entertainment                                 float64
# age                                           float64
# dtype: object
